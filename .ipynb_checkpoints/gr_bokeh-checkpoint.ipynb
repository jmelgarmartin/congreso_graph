# %%
import pickle
import pandas as pd
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.models import FactorRange
from bokeh.io import show
from bokeh.layouts import row, column
from bokeh.models.widgets import Div
from bokeh.models import Title
from bokeh.models.widgets import Select
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1697">Loading BokehJS ...</span>
#     </div>

# %%
with open('debate.pickle', 'rb') as handle:
    datos = pickle.load(handle)

# %%
def generate_data(grupo):
    debate = datos[datos['grupo'] == grupo].iloc[0][0]
    palabras_mas_dichas = datos[datos['grupo'] == grupo].iloc[0][2]
    palabras_acumuladas = datos[datos['grupo'] == grupo].iloc[0][3]
    palabras_hist = palabras_acumuladas = datos[datos['grupo'] == grupo].iloc[0][4]
    
    x = palabras_mas_dichas['palabra']
    y = palabras_mas_dichas['numero_veces']
    source = ColumnDataSource(data={'x': x, 'y': y})
    p1 = figure(x_range=FactorRange(*x),height=250, width=300, 
                title='Palabras más repetidas', toolbar_location=None, active_drag=None, active_scroll=None)
    
    x = palabras_acumuladas['palabra']
    y = palabras_acumuladas['veces']
    source = ColumnDataSource(data={'x': x, 'y': y})
    p2 = figure(x_range=FactorRange(*x),height=250, width=300, 
                title='histórico acumulado', toolbar_location=None, active_drag=None, active_scroll=None)
    
    x = palabras_hist['palabra']
    y = palabras_hist['veces']
    source = ColumnDataSource(data={'x': x, 'y': y})
    p3 = figure(x_range=FactorRange(*x),height=250, width=300, 
                title='histórico total', toolbar_location=None, active_drag=None, active_scroll=None)
    
    p1.vbar(x='x', top='y', width=0.9, source=source, color='#FA4F00')
    p2.vbar(x='x', top='y', width=0.9, source=source, color='#FA4F00')
    p3.vbar(x='x', top='y', width=0.9, source=source, color='#FA4F00')
    
    p1.y_range.start = 0
    p1.x_range.range_padding = 0.1
    p1.xaxis.major_label_orientation = 1
    p1.xgrid.grid_line_color = None

    p2.y_range.start = 0
    p2.x_range.range_padding = 0.1
    p2.xaxis.major_label_orientation = 1
    p2.xgrid.grid_line_color = None

    p3.y_range.start = 0
    p3.x_range.range_padding = 0.1
    p3.xaxis.major_label_orientation = 1
    p3.xgrid.grid_line_color = None
    
    show(column(select, row(p1, p2, p3)), notebook_handle=True)

# %%
grupos = datos['grupo'].drop_duplicates()

# %%
def update_plot(attr, old, new):
    print(select.value)

# %%
select = Select(title="Grupo:",  options=grupos.values.tolist())
select.on_change(generate_data(select.value))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-7ae75eac4b72> in <module>
#       1 select = Select(title="Grupo:",  options=grupos.values.tolist())
# ----> 2 select.on_change(generate_data(select.value))
#
# <ipython-input-85-595d8503aa7f> in generate_data(grupo)
#       1 def generate_data(grupo):
# ----> 2     debate = datos[datos['grupo'] == grupo].iloc[0][0]
#       3     palabras_mas_dichas = datos[datos['grupo'] == grupo].iloc[0][2]
#       4     palabras_acumuladas = datos[datos['grupo'] == grupo].iloc[0][3]
#       5     palabras_hist = palabras_acumuladas = datos[datos['grupo'] == grupo].iloc[0][4]
#
# ~\AppData\Local\Continuum\anaconda3\envs\congreso\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# ...

# %%
generate_data(grupos[0])
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html
#   <div class="bk-root" id="0524bd57-bc8f-4398-827c-ab8a77ae599c" data-root-id="5771"></div>

# %%
# Out:
#   <div class="bk-root" id="d9998af3-8463-45b7-aea1-c8431ed49808" data-root-id="4315"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[83]</strong>&gt;</code></p>

# %%
for data in datos[datos['grupo'] == 'Grupo Ciudadanos'].iterrows():
    print(data[1][0])
    print(data[1][1])
    print(data[1][2])
# Out:
# 00_INVESTIDURA
# Grupo Ciudadanos
#        palabra  numero_veces
# 0      sánchez            79
# 1      acuerdo            58
# 2       españa            55
# 3     gobierno            45
# 4    españoles            39
# 5      partido            38
# 6     esquerra            30
# 7     cataluña            28
# 8        tener            22
# 9         país            20
# 10  socialista            19
# 11         pnv            18
# 12     podemos            18
# 13      socios            17
# 14       pedro            16
# 2020_02_04
# Grupo Ciudadanos
#          palabra  numero_veces
# 0       gobierno            34
# 1     ciudadanos            16
# 2        decreto            15
# 3      pensiones            13
# 4           real            11
# 5       impuesto            10
# 6       personas            10
# 7        medidas             9
# 8            año             8
# 9        laboral             8
# 10      trabajar             8
# 11       creemos             6
# ...

# %%
datos['grupo'].drop_duplicates()
# Out:
# 0     Grupo Ciudadanos
# 1       Grupo EH Bildu
# 2          Grupo Mixto
# 3         Grupo Plural
# 4        Grupo Podemos
# 5        Grupo Popular
# 6    Grupo Republicano
# 7     Grupo Socialista
# 8          Grupo Vasco
# 9            Grupo Vox
# Name: grupo, dtype: object

# %%
def pr(a, b):
    return a + 1, b + 1

# %%
a = 1
b = 1
a, b = pr(a, b)
print(a)
print(b)
# Out:
# 2
# 2
